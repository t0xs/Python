# %%
salariohora= salario1/8
salario1 = 5000
salario2 = 3000
salario3 = salario1 - salario2
salario4 = salario1+salario2

salariobruto = salariohora*8
print("O seu salario é", salariohora*2)
# Out:
# O seu salario é 1250.0

# %%
nome = "print"

# %%
nome="gustavo real og"

# %%
nome= input('Qual seu nome :')
salario = int(input('Qual seu salario: '))
salariohora = salario1/8
salariobruto = salariohora*8

print(nome, 'O seu salario é : ', salariohora, 'voce trabalhou 8 horas e ganhou ', salariobruto)
# Out:
# Qual seu nome :gustavo
# Qual seu salario: 5000
# gustavo O seu salario é :  625.0 voce trabalhou 8 horas e ganhou  5000.0

# %%
segundos = input('Quantos segundos?')
tot_seg = int(segundos)

horas = tot_seg //3600
seg_resto = tot_seg % 3600
minutos = seg_resto // 60
seg_resto_final = seg_resto % 60

print(horas, " hr", minutos, " min", seg_resto_final, " seg")
# Out:
# Quantos segundos?5454
# 1  hr 30  min 54  seg

# %%
segundos = input('Quantos segundos?')
tot_seg = int(segundos)

horas = tot_seg // 3600
seg_resto = tot_seg % 3600
minutos= seg_resto // 60

print (vai, " hr" , minutos, " min", seg_resto )
# Out:
# 3600

# %%
segundos = input('Quantos segundos?')
tot_seg = int(segundos)

horas = tot_seg // 3600
seg_resto = tot_seg % 3600
minutos = seg_resto // 60
seg_resto_final = seg_resto %60

print (horas, "hr", minutos, " min", seg_resto_final, " seg")
# Out:
# Quantos segundos?120
# 0 hr 2  min 0  seg

# %%
2965 % 60
# Out:
# 25

# %%
1*6
# Out:
# 6

# %%
# Out:
# 2.0
